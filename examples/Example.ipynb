# %%
import numpy as np
import forecaster as fct

# %%
data = np.random.rand(1000, 100)

# %%
f = fct.Forecaster(
    data=data,
    forecast_length=10,
)

# %%
f.fit()
# Out:
# [[02/16/2018 04:27:48 PM]]
# Network hyper-parameters:
# {'batch_size': 128,
#  'checkpoint_dir': 'tf-data/checkpoints',
#  'early_stopping_steps': 35,
#  'enable_parameter_averaging': False,
#  'grad_clip': 5,
#  'keep_prob': 1,
#  'learning_rate': 0.01,
#  'log_dir': 'tf-data/logs',
#  'log_interval': 7,
#  'logger': <Logger RNNModel.2018-02-16.16-27-48.572629 (INFO)>,
#  'loss_averaging_window': 7,
#  'lr_schedule': None,
#  'min_steps_to_checkpoint': 7,
#  'name': 'rnn',
#  'num_restarts': 3,
#  'num_training_steps': 700,
#  'optimizer': 'adam',
#  'prediction_dir': 'tf-data/predictions',
#  'reader': <forecaster.rnn_data_reader.RNNDataReader object at 0x7f53aa7b8240>,
#  'regularization_constant': 0.0,
#  'state_size': [300],
#  'warm_start_init_step': 0}
# [[02/16/2018 04:27:48 PM]]
# [[02/16/2018 04:27:48 PM]] Data dimensions:
# [[02/16/2018 04:27:48 PM]]     [[data]] (1000, 100)
# [[02/16/2018 04:27:48 PM]] Split seed = 923
# [[02/16/2018 04:27:48 PM]]
# ...

# %%
f.predict()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-66b0e5927447> in <module>()
# ----> 1 f.predict()
#
# /mnt/WD Black/Dropbox/JuanCode/Insight/Project/forecaster/forecaster.py in predict(self)
#      12
#      13         def predict(self):
# ---> 14                 return self.model.predict()[:, -self.forecast_length:]
#      15
#      16         def get_model(self):
#
# /mnt/WD Black/Dropbox/JuanCode/Insight/Project/forecaster/rnn_model.py in predict(self, batch_size)
#      84     def predict(self, batch_size=1000):
#      85         preds = []
# ---> 86         test_generator = self.reader.test_batch_generator(batch_size)
#      87         for i, test_batch_df in enumerate(test_generator):
#      88             test_feed_dict = {
#
# AttributeError: 'RNNDataReader' object has no attribute 'test_batch_generator'
